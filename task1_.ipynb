# %% [markdown]
# **1. Italic Syntax**
#
# _Divya_
#
# **2. Bold text**
#
# __Riya__

# %% [markdown]
# **3. blockquote**
#
# >UMREDKAR

# %% [markdown]
# **4. Image**
#
# ![image.png](attachment:3c8f609d-ffb4-4704-ae12-0f16836e3040.png)

# %% [markdown]
# **5. Table**
#
# | Jupyter  | Task     |
# |----------|----------|
# | Code     | Task_1   |
# | Markdown | Task_2   |

# %% [markdown]
# **6. Horizontal Rule**
#
# ---
# ---

# %% [markdown]
# **7. Number List**
#
# 1. One
# 2. Two

# %% [markdown]
# **8. Bullet Point**
#
# - Excel
# - SQL

# %% [markdown]
# **9. Strikethrough**
#
# ~~Jupyter Notebook~~

# %% [markdown]
# **10. Headers**
# # Main Title
# ## Section Title
# ### Subsection Title

# %% [markdown]
# **11. Checkbox**
# - [x] Completed Task
# - [ ] Incomplete Task

# %% [markdown]
# **12. Defination**
#
# EXCEL
# : Definition for Excel
#
# SQL
# : Definition for SQL

# %% [markdown]
# **13. Highlight**
#
# Welcome to <span style="color: orange;">Jupyter</span> <span style="color: red;">Taks_1.</span>

# %% [markdown]
# **14. Mathematics**
#
# $E = mc^2$

# %% [markdown]
# **15. Link**
#
# [Click here to visit Google](https://www.google.com)
